# %%
# Demo notebook for Monte Carlo integration

import matplotlib.pyplot as plt
from monte_carlo import monte_carlo_integral, func

# Parameters
a, b = 0.5, 1.5
N = 100_000

# Estimate integral
integral_est, Ymax = monte_carlo_integral(a, b, N)

print(f"Monte Carlo estimate: {integral_est:.6f}")

# Plot function and random points
x = np.linspace(a, b, 1000)
y = func(x)

plt.figure(figsize=(8,5))
plt.plot(x, y, label='f(x) = 0.5*exp(x) + 1', color='blue')
plt.title("Function f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()
